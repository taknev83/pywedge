# %% [markdown]
# <a href="https://colab.research.google.com/github/taknev83/pywedge/blob/main/Example_Pywedge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Pywedge is a [pip installable](https://pypi.org/project/pywedge/) Python package that intends to,
# 1. ***Make multiple charts*** in a single line of code, to enable the user to quickly read through the charts and can make informed choices in pre-processing steps

# %% [markdown]
# 2. ***Quickly preprocess*** the data by taking the user’s preferred choice of pre-processing techniques & it returns the cleaned datasets to the user in the first step.

# %% [markdown]
# 3. Make a ***baseline model summary***, which can return ten various baseline models, which can point the user to explore the best performing baseline model.

# %% [markdown]
# ***Pywedge intends to help the user by quickly making charts, preprocessing the data and to rightly point out the best performing baseline model for the given dataset so that the user can spend quality time tuning such a model algorithm.***

# %% [markdown]
# #### Installing pywedge

# %%
# !pip install pywedge

# %% [markdown]
# #### Importing the package

# %%
import pywedge as pw

# %%
import pandas as pd
train = pd.read_csv('https://raw.githubusercontent.com/taknev83/datasets/master/credit_risk_train.csv')
test = pd.read_csv('https://raw.githubusercontent.com/taknev83/datasets/master/credit_risk_test.csv')

# %%
train.head()
# Out:
#   checking_status  duration                    credit_history  \
# 0   'no checking'        18  'critical/other existing credit'
# 1            '<0'        24                   'existing paid'
# 2   'no checking'        36             'no credits/all paid'
# 3   'no checking'        15                   'existing paid'
# 4            '<0'        21                   'existing paid'
#
#                purpose  credit_amount savings_status employment  \
# 0             radio/tv           1800         '<100'   '1<=X<4'
# 1             radio/tv           2439         '<100'       '<1'
# 2              repairs           2613         '<100'   '1<=X<4'
# 3            education           4623   '100<=X<500'   '1<=X<4'
# 4  furniture/equipment           3599         '<100'   '4<=X<7'
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# 1                       4  'female div/dep/mar'          none  ...
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   checking_status         800 non-null    object
#  1   duration                800 non-null    int64
#  2   credit_history          800 non-null    object
#  3   purpose                 800 non-null    object
#  4   credit_amount           800 non-null    int64
#  5   savings_status          800 non-null    object
#  6   employment              800 non-null    object
#  7   installment_commitment  800 non-null    int64
#  8   personal_status         800 non-null    object
#  9   other_parties           800 non-null    object
#  10  residence_since         800 non-null    int64
#  11  property_magnitude      800 non-null    object
#  12  age                     800 non-null    int64
#  13  other_payment_plans     800 non-null    object
# ...

# %% [markdown]
# ##### Instantiate the Pywedge_Charts class, which takes the following inputs & returns the Charts widget

# %% [markdown]
#  Inputs:
#
#  1. Dataframe
#
#  2. c = any redundant column to be removed (like ID column etc., at present supports a single column removal, the subsequent version will provision multiple column removal requirements)
#
#  3. y = target column name as a string

# %%
mc = pw.Pywedge_Charts(train, c=None, y = 'class')

# %% [markdown]
# Call the make_charts method from the instantiated class, which renders the following charts widget.

# %% [markdown]
# ## Please run the colab file to have the charts rendered.

# %%
charts = mc.make_charts()
# Out:
# HTML(value='<h2>Pywedge Make_Charts </h2>')
# ...
# HTML(value='<h4><em>Charts compiled by Pywedge make_charts </em></h4>')

# %% [markdown]
# # Please find a preview of Pywedge-Make_Charts in Voila Gridstack dashboard below

# %% [markdown]
# ![pywedge.gif](data:image/gif;base64,...)

# %% [markdown]
# This piece of code is to have Max width in Jupyter Notebook

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container {width:100% !important; }</style"))
# Out:
# <style>.container {width:100% !important; }</style

# %% [markdown]
# Instantiate Pre_process_data class & call dataframe_clean method
#
# The Pre_process_data class takes the following inputs,
#
# **Inputs:**
#
# 1. train = train dataframe
# 2. test = test dataframe
# 3. c = any redundant column to be removed (like ID column etc., at present supports a single column removal, subsequent version will provision multiple column removal requirements)
# 4. y = target column name as a string
# 5. type = Classification(Default) / Regression
#
# The dataframe_clean method returns the following,
#
# **Returns:**
#
# 1. new_X (cleaned feature columns in dataframe)
# 2. new_y (cleaned target column in dataframe)
# 3. new_test (cleaned stand out test dataset)

# %%
ppd = pw.Pre_process_data(train, test, c=None, y='class')

# %% [markdown]
# The dataframe_clean method ***interactivly*** asks the user for the ***choice of pre processing steps*** & provides a missing value & class balance summaries.
#
# ***Quick link to respective library pages provides for reference if required***

# %%
new_X, new_y, new_test = ppd.dataframe_clean()
# Out:
# Reading the datasets...
# ******************************************
#
# Train Dataframe summary...
# ******************************************
#
# Your selected train dataframe has 21 columns and 800 Rows.
# There are 0 columns that have missing values.
# Empty DataFrame
# Columns: [Zero Values, Missing Values, % of Total Values, Total Zero Missing Values, % Total Zero Missing Values, Data Type]
# Index: []
# ******************************************
# Class balance summary table
# good    560
# bad     240
# Name: class, dtype: int64
#
#  Class imbalance % is  30.0 %
# Starting data cleaning...
# ******************************************
# Do you want to use get_dummies or catcodes to convert categorical to numerical?
# 	press 1 for catcodes - Quick info link - https://bit.ly/3lruqtf
# 	press 2 for getdummies - Quick info link - https://bit.ly/3d76p7A
# 1
# Comleted categorical column transformation
# ******************************************
# ...

# %% [markdown]
# #### Assign the cleaned datasets to new variables for further use

# %%
X = new_X
y = new_y
so_test = new_test

# %%
X
# Out:
#       checking_status  duration  credit_history   purpose  credit_amount  \
# 0            1.151421 -0.249201       -1.114284  1.173888      -0.536775
# 1           -0.451950  0.244063        0.760431  1.173888      -0.313741
# 2            1.151421  1.230589        1.697789  1.582020      -0.253009
# 3            1.151421 -0.495832        0.760431 -0.050506       0.448553
# 4           -0.451950 -0.002569        0.760431  0.357625       0.091141
# ...               ...       ...             ...       ...            ...
# 1115        -1.232079 -0.742464        0.760431  0.379574      -0.505905
# 1116        -0.451950  0.244063       -0.923184  1.011425      -0.761221
# 1117        -0.631407  0.899339       -0.904457  0.040854       1.355535
# 1118        -0.451950  1.406397        0.760431 -0.939502       1.708595
# 1119        -1.253636  0.226676        0.760431 -1.274901      -0.572878
#
#       savings_status  employment  installment_commitment  personal_status  \
# ...

# %% [markdown]
# Instantiate the baseline model class with new variables from cleaned datasets (X & y)

# %%
blm = pw.baseline_model(X,y)

# %% [markdown]
# Call the classification_summary method from baseline_model class
# The classification_summary method provides ***Top 10 feature importance*** (calculated using Adaboost feature importance) and ***interactively takes the test size from the user.***
#
# ***Then the classification_summary provides baseline models of 10 different algorithms.***

# %%
blm.classification_summary()
# Out:
# Starting classification_summary...
# TOP 10 FEATURE IMPORTANCE
# checking_status           0.16
# job                       0.08
# purpose                   0.08
# credit_amount             0.08
# property_magnitude        0.08
# installment_commitment    0.08
# duration                  0.06
# credit_history            0.06
# own_telephone             0.04
# employment                0.04
# dtype: float64
# Please enter test size (for eg. please enter 0.20 for 20% test size):
# 0.25
# Logistic       | acc_score = 0.696 | roc_score = 0.695 | f1_score(macro) = 0.695 | Train time = 0.019s | Pred. time = 0.000s
# KNN(3)         | acc_score = 0.689 | roc_score = 0.698 | f1_score(macro) = 0.685 | Train time = 0.007s | Pred. time = 0.046s
# Decision Tree  | acc_score = 0.714 | roc_score = 0.715 | f1_score(macro) = 0.714 | Train time = 0.008s | Pred. time = 0.001s
# Random Forest  | acc_score = 0.782 | roc_score = 0.785 | f1_score(macro) = 0.782 | Train time = 0.053s | Pred. time = 0.003s
# ...
